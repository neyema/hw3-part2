# %%
import cv2
import numpy as np
from matplotlib import pyplot
import pickle as pkl
from tensorflow import keras
from keras import Model
from keras.layers import Dense, Flatten
from keras.callbacks import EarlyStopping, Callback

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Images Generators

# %%
# !cp /content/drive/MyDrive/102flowers/data1.zip /content/data1.zip

# %%
# !unzip /content/data1.zip

# %%
with open("/content/drive/MyDrive/102flowers/pkl-1/X_train.pkl", "rb") as f:
  X_train = pkl.load(f)
with open("/content/drive/MyDrive/102flowers/pkl-1/y_train.pkl", "rb") as f:
  y_train = pkl.load(f)

train_imgs = []
for i, path in enumerate(X_train):
  img = path.split('\\')[-1]
  train_imgs.append(f"/content/train/{y_train[i]}/{img}")

# %%
with open("/content/drive/MyDrive/102flowers/pkl-1/X_val.pkl", "rb") as f:
  X_val = pkl.load(f)
with open("/content/drive/MyDrive/102flowers/pkl-1/y_val.pkl", "rb") as f:
  y_val = pkl.load(f)

val_imgs = []
for i, path in enumerate(X_val):
  img = path.split('\\')[-1]
  val_imgs.append(f"/content/val/{y_val[i]}/{img}")

# %%
with open("/content/drive/MyDrive/102flowers/pkl-1/X_test.pkl", "rb") as f:
  X_test = pkl.load(f)
with open("/content/drive/MyDrive/102flowers/pkl-1/y_test.pkl", "rb") as f:
  y_test = pkl.load(f)

test_imgs = []
for i, path in enumerate(X_test):
  img = path.split('\\')[-1]
  test_imgs.append(f"/content/test/{y_test[i]}/{img}")

# %% [markdown]
# I will implement a generator class, instead of loading all the data to RAM.

# %%
class FlowersImagesGenerator(keras.utils.Sequence):

  def __init__(self, images_paths, y, num_classes=102, batch_size=32, *args, **kwargs):
    self.images_paths = images_paths
    self.y = y
    self.num_classes = num_classes
    self.batch_size = batch_size

  def __len__(self):
    return (len(self.images_paths) // self.batch_size)

  def __getitem__(self, index):
    batch_images = self.images_paths[self.batch_size*index : self.batch_size*(index+1)]
    y_batch = self.y[self.batch_size*index : self.batch_size*(index+1)]

    X = [cv2.resize(cv2.imread(img_path)/255, (256,256)) for img_path in batch_images]
    y_onehot = np.zeros((y_batch.shape[0], self.num_classes))
    for i, val in enumerate(y_batch):
      y_onehot[i, val - 1] = 1  # y classes are 1 to 102
    return np.array(X), y_onehot

# %%
num_classes = 102

# %% [markdown]
# # VGG19

# %%
vgg19 = keras.applications.vgg19.VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(256, 256, 3),
    classes=num_classes,
    classifier_activation='softmax')

# %%
for layer in vgg19.layers:
  layer.trainable = False

# %%
out = Flatten()(vgg19.output)
out = Dense(4096, activation='relu', name="fc1")(out)
out = Dense(4096, activation='relu', name="fc2")(out)
predictions = Dense(num_classes, activation='softmax', name="predictions")(out)
model = Model(inputs=vgg19.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_4 (Flatten)         (None, 32768)             0
#
#  fc1 (Dense)                 (None, 4096)              134221824
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 102)               417894
#
# =================================================================
# Total params: 171,445,414
# Trainable params: 151,421,030
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy', 'categorical_accuracy'])

# %% [markdown]
# I will create a custom callback for logging the accuracy and loss on the test set in each epoch, as the instructions specify.

# %%
class TestMetricsCallback(Callback):
  def __init__(self):
    self.epoch_test_loss = []
    self.epoch_test_accuracy = []
    self.epoch_test_categorical_accuracy = []

  def on_epoch_end(self, epoch, logs=None):
    test_generator = FlowersImagesGenerator(images_paths=test_imgs, y=y_test)
    loss, accuracy, categorical_accuracy = self.model.evaluate(test_generator)
    self.epoch_test_loss.append(loss)
    self.epoch_test_accuracy.append(accuracy)
    self.epoch_test_categorical_accuracy.append(categorical_accuracy)

# %%
train_generator = FlowersImagesGenerator(images_paths=train_imgs, y=y_train)
val_generator = FlowersImagesGenerator(images_paths=val_imgs, y=y_val)

# %%
early_stop_callback = EarlyStopping(monitor='val_loss', mode='min')
test_metrics_callback = TestMetricsCallback()
history = model.fit(train_generator, validation_data=val_generator, epochs=50,
                    callbacks=[test_metrics_callback], verbose=2)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 18s 280ms/step - loss: 2.5724 - accuracy: 0.3271 - categorical_accuracy: 0.3271
# 127/127 - 79s - loss: 5.5809 - accuracy: 0.1737 - categorical_accuracy: 0.1737 - val_loss: 2.5028 - val_accuracy: 0.3383 - val_categorical_accuracy: 0.3383 - 79s/epoch - 622ms/step
# Epoch 2/50
# 64/64 [==============================] - 19s 295ms/step - loss: 1.6794 - accuracy: 0.5386 - categorical_accuracy: 0.5386
# 127/127 - 74s - loss: 1.7093 - accuracy: 0.5322 - categorical_accuracy: 0.5322 - val_loss: 1.6451 - val_accuracy: 0.5456 - val_categorical_accuracy: 0.5456 - 74s/epoch - 585ms/step
# Epoch 3/50
# 64/64 [==============================] - 18s 279ms/step - loss: 1.7733 - accuracy: 0.5371 - categorical_accuracy: 0.5371
# 127/127 - 72s - loss: 0.7283 - accuracy: 0.7889 - categorical_accuracy: 0.7889 - val_loss: 1.7783 - val_accuracy: 0.5327 - val_categorical_accuracy: 0.5327 - 72s/epoch - 568ms/step
# Epoch 4/50
# 64/64 [==============================] - 18s 278ms/step - loss: 1.5561 - accuracy: 0.6113 - categorical_accuracy: 0.6113
# 127/127 - 72s - loss: 0.3854 - accuracy: 0.8816 - categorical_accuracy: 0.8816 - val_loss: 1.4994 - val_accuracy: 0.6230 - val_categorical_accuracy: 0.6230 - 72s/epoch - 565ms/step
# Epoch 5/50
# 64/64 [==============================] - 18s 282ms/step - loss: 1.6656 - accuracy: 0.6274 - categorical_accuracy: 0.6274
# 127/127 - 75s - loss: 0.1979 - accuracy: 0.9373 - categorical_accuracy: 0.9373 - val_loss: 1.6456 - val_accuracy: 0.6225 - val_categorical_accuracy: 0.6225 - 75s/epoch - 592ms/step
# Epoch 6/50
# 64/64 [==============================] - 18s 274ms/step - loss: 1.9580 - accuracy: 0.6045 - categorical_accuracy: 0.6045
# 127/127 - 77s - loss: 0.2318 - accuracy: 0.9193 - categorical_accuracy: 0.9193 - val_loss: 1.9475 - val_accuracy: 0.6111 - val_categorical_accuracy: 0.6111 - 77s/epoch - 604ms/step
# Epoch 7/50
# 64/64 [==============================] - 18s 280ms/step - loss: 1.8388 - accuracy: 0.6177 - categorical_accuracy: 0.6177
# 127/127 - 74s - loss: 0.1299 - accuracy: 0.9599 - categorical_accuracy: 0.9599 - val_loss: 1.7051 - val_accuracy: 0.6419 - val_categorical_accuracy: 0.6419 - 74s/epoch - 579ms/step
# Epoch 8/50
# 64/64 [==============================] - 19s 290ms/step - loss: 2.1696 - accuracy: 0.6021 - categorical_accuracy: 0.6021
# 127/127 - 75s - loss: 0.0701 - accuracy: 0.9786 - categorical_accuracy: 0.9786 - val_loss: 2.1308 - val_accuracy: 0.6002 - val_categorical_accuracy: 0.6002 - 75s/epoch - 588ms/step
# Epoch 9/50
# 64/64 [==============================] - 18s 279ms/step - loss: 1.7873 - accuracy: 0.6484 - categorical_accuracy: 0.6484
# 127/127 - 75s - loss: 0.1457 - accuracy: 0.9535 - categorical_accuracy: 0.9535 - val_loss: 1.7600 - val_accuracy: 0.6498 - val_categorical_accuracy: 0.6498 - 75s/epoch - 587ms/step
# Epoch 10/50
# 64/64 [==============================] - 18s 271ms/step - loss: 2.0026 - accuracy: 0.6367 - categorical_accuracy: 0.6367
# 127/127 - 72s - loss: 0.1267 - accuracy: 0.9616 - categorical_accuracy: 0.9616 - val_loss: 1.8374 - val_accuracy: 0.6414 - val_categorical_accuracy: 0.6414 - 72s/epoch - 563ms/step
# Epoch 11/50
# 64/64 [==============================] - 19s 297ms/step - loss: 2.1188 - accuracy: 0.6279 - categorical_accuracy: 0.6279
# 127/127 - 75s - loss: 0.1336 - accuracy: 0.9557 - categorical_accuracy: 0.9557 - val_loss: 2.0618 - val_accuracy: 0.6235 - val_categorical_accuracy: 0.6235 - 75s/epoch - 589ms/step
# Epoch 12/50
# 64/64 [==============================] - 19s 296ms/step - loss: 1.8158 - accuracy: 0.6582 - categorical_accuracy: 0.6582
# 127/127 - 73s - loss: 0.0816 - accuracy: 0.9732 - categorical_accuracy: 0.9732 - val_loss: 1.7337 - val_accuracy: 0.6672 - val_categorical_accuracy: 0.6672 - 73s/epoch - 578ms/step
# Epoch 13/50
# 64/64 [==============================] - 20s 311ms/step - loss: 2.1569 - accuracy: 0.6348 - categorical_accuracy: 0.6348
# 127/127 - 75s - loss: 0.0287 - accuracy: 0.9916 - categorical_accuracy: 0.9916 - val_loss: 2.0184 - val_accuracy: 0.6513 - val_categorical_accuracy: 0.6513 - 75s/epoch - 588ms/step
# Epoch 14/50
# 64/64 [==============================] - 18s 278ms/step - loss: 2.6327 - accuracy: 0.6177 - categorical_accuracy: 0.6177
# 127/127 - 75s - loss: 0.0763 - accuracy: 0.9759 - categorical_accuracy: 0.9759 - val_loss: 2.3601 - val_accuracy: 0.6116 - val_categorical_accuracy: 0.6116 - 75s/epoch - 591ms/step
# Epoch 15/50
# 64/64 [==============================] - 18s 279ms/step - loss: 3.1182 - accuracy: 0.5620 - categorical_accuracy: 0.5620
# 127/127 - 72s - loss: 0.1952 - accuracy: 0.9427 - categorical_accuracy: 0.9427 - val_loss: 2.8256 - val_accuracy: 0.5660 - val_categorical_accuracy: 0.5660 - 72s/epoch - 565ms/step
# Epoch 16/50
# 64/64 [==============================] - 18s 277ms/step - loss: 2.9305 - accuracy: 0.5591 - categorical_accuracy: 0.5591
# 127/127 - 72s - loss: 0.2106 - accuracy: 0.9365 - categorical_accuracy: 0.9365 - val_loss: 2.6286 - val_accuracy: 0.5774 - val_categorical_accuracy: 0.5774 - 72s/epoch - 567ms/step
# Epoch 17/50
# 64/64 [==============================] - 18s 274ms/step - loss: 2.8889 - accuracy: 0.5542 - categorical_accuracy: 0.5542
# 127/127 - 71s - loss: 0.1877 - accuracy: 0.9491 - categorical_accuracy: 0.9491 - val_loss: 2.9071 - val_accuracy: 0.5670 - val_categorical_accuracy: 0.5670 - 71s/epoch - 557ms/step
# Epoch 18/50
# 64/64 [==============================] - 19s 287ms/step - loss: 2.4430 - accuracy: 0.6172 - categorical_accuracy: 0.6172
# 127/127 - 75s - loss: 0.1311 - accuracy: 0.9596 - categorical_accuracy: 0.9596 - val_loss: 2.4418 - val_accuracy: 0.6101 - val_categorical_accuracy: 0.6101 - 75s/epoch - 591ms/step
# Epoch 19/50
# 64/64 [==============================] - 18s 279ms/step - loss: 2.8856 - accuracy: 0.5879 - categorical_accuracy: 0.5879
# 127/127 - 74s - loss: 0.0859 - accuracy: 0.9732 - categorical_accuracy: 0.9732 - val_loss: 2.7999 - val_accuracy: 0.5933 - val_categorical_accuracy: 0.5933 - 74s/epoch - 584ms/step
# Epoch 20/50
# 64/64 [==============================] - 19s 290ms/step - loss: 2.3599 - accuracy: 0.6338 - categorical_accuracy: 0.6338
# 127/127 - 76s - loss: 0.0564 - accuracy: 0.9825 - categorical_accuracy: 0.9825 - val_loss: 2.3024 - val_accuracy: 0.6424 - val_categorical_accuracy: 0.6424 - 76s/epoch - 600ms/step
# Epoch 21/50
# 64/64 [==============================] - 18s 275ms/step - loss: 2.5356 - accuracy: 0.6411 - categorical_accuracy: 0.6411
# 127/127 - 74s - loss: 0.0440 - accuracy: 0.9862 - categorical_accuracy: 0.9862 - val_loss: 2.4370 - val_accuracy: 0.6438 - val_categorical_accuracy: 0.6438 - 74s/epoch - 582ms/step
# Epoch 22/50
# 64/64 [==============================] - 18s 272ms/step - loss: 2.3674 - accuracy: 0.6411 - categorical_accuracy: 0.6411
# 127/127 - 72s - loss: 0.0774 - accuracy: 0.9761 - categorical_accuracy: 0.9761 - val_loss: 2.4591 - val_accuracy: 0.6344 - val_categorical_accuracy: 0.6344 - 72s/epoch - 568ms/step
# Epoch 23/50
# 64/64 [==============================] - 18s 276ms/step - loss: 2.8333 - accuracy: 0.6143 - categorical_accuracy: 0.6143
# 127/127 - 74s - loss: 0.1749 - accuracy: 0.9560 - categorical_accuracy: 0.9560 - val_loss: 2.6609 - val_accuracy: 0.6195 - val_categorical_accuracy: 0.6195 - 74s/epoch - 583ms/step
# Epoch 24/50
# 64/64 [==============================] - 19s 296ms/step - loss: 2.8470 - accuracy: 0.6279 - categorical_accuracy: 0.6279
# 127/127 - 73s - loss: 0.0455 - accuracy: 0.9875 - categorical_accuracy: 0.9875 - val_loss: 2.7209 - val_accuracy: 0.6111 - val_categorical_accuracy: 0.6111 - 73s/epoch - 576ms/step
# Epoch 25/50
# 64/64 [==============================] - 18s 278ms/step - loss: 2.9063 - accuracy: 0.6235 - categorical_accuracy: 0.6235
# 127/127 - 74s - loss: 0.0602 - accuracy: 0.9811 - categorical_accuracy: 0.9811 - val_loss: 2.8155 - val_accuracy: 0.6215 - val_categorical_accuracy: 0.6215 - 74s/epoch - 584ms/step
# Epoch 26/50
# 64/64 [==============================] - 19s 291ms/step - loss: 3.0122 - accuracy: 0.5972 - categorical_accuracy: 0.5972
# 127/127 - 75s - loss: 0.1226 - accuracy: 0.9712 - categorical_accuracy: 0.9712 - val_loss: 2.9537 - val_accuracy: 0.6081 - val_categorical_accuracy: 0.6081 - 75s/epoch - 587ms/step
# Epoch 27/50
# 64/64 [==============================] - 18s 275ms/step - loss: 3.1285 - accuracy: 0.6064 - categorical_accuracy: 0.6064
# 127/127 - 71s - loss: 0.1396 - accuracy: 0.9611 - categorical_accuracy: 0.9611 - val_loss: 3.0414 - val_accuracy: 0.6032 - val_categorical_accuracy: 0.6032 - 71s/epoch - 562ms/step
# Epoch 28/50
# 64/64 [==============================] - 18s 283ms/step - loss: 3.2341 - accuracy: 0.5635 - categorical_accuracy: 0.5635
# 127/127 - 75s - loss: 0.0965 - accuracy: 0.9732 - categorical_accuracy: 0.9732 - val_loss: 3.2287 - val_accuracy: 0.5833 - val_categorical_accuracy: 0.5833 - 75s/epoch - 588ms/step
# Epoch 29/50
# 64/64 [==============================] - 18s 283ms/step - loss: 3.2334 - accuracy: 0.6138 - categorical_accuracy: 0.6138
# 127/127 - 73s - loss: 0.1133 - accuracy: 0.9710 - categorical_accuracy: 0.9710 - val_loss: 3.2271 - val_accuracy: 0.6161 - val_categorical_accuracy: 0.6161 - 73s/epoch - 576ms/step
# Epoch 30/50
# 64/64 [==============================] - 18s 284ms/step - loss: 3.2523 - accuracy: 0.6143 - categorical_accuracy: 0.6143
# 127/127 - 75s - loss: 0.0731 - accuracy: 0.9801 - categorical_accuracy: 0.9801 - val_loss: 3.0446 - val_accuracy: 0.5977 - val_categorical_accuracy: 0.5977 - 75s/epoch - 593ms/step
# Epoch 31/50
# 64/64 [==============================] - 18s 281ms/step - loss: 3.1647 - accuracy: 0.6108 - categorical_accuracy: 0.6108
# 127/127 - 74s - loss: 0.0861 - accuracy: 0.9788 - categorical_accuracy: 0.9788 - val_loss: 3.0686 - val_accuracy: 0.6126 - val_categorical_accuracy: 0.6126 - 74s/epoch - 581ms/step
# Epoch 32/50
# 64/64 [==============================] - 18s 282ms/step - loss: 3.2105 - accuracy: 0.6260 - categorical_accuracy: 0.6260
# 127/127 - 73s - loss: 0.0778 - accuracy: 0.9818 - categorical_accuracy: 0.9818 - val_loss: 3.1007 - val_accuracy: 0.6210 - val_categorical_accuracy: 0.6210 - 73s/epoch - 577ms/step
# Epoch 33/50
# 64/64 [==============================] - 18s 280ms/step - loss: 3.0690 - accuracy: 0.6392 - categorical_accuracy: 0.6392
# 127/127 - 76s - loss: 0.0147 - accuracy: 0.9963 - categorical_accuracy: 0.9963 - val_loss: 2.9733 - val_accuracy: 0.6265 - val_categorical_accuracy: 0.6265 - 76s/epoch - 602ms/step
# Epoch 34/50
# 64/64 [==============================] - 18s 277ms/step - loss: 3.4423 - accuracy: 0.5879 - categorical_accuracy: 0.5879
# 127/127 - 72s - loss: 0.0507 - accuracy: 0.9860 - categorical_accuracy: 0.9860 - val_loss: 3.3586 - val_accuracy: 0.5933 - val_categorical_accuracy: 0.5933 - 72s/epoch - 568ms/step
# Epoch 35/50
# 64/64 [==============================] - 19s 298ms/step - loss: 3.8133 - accuracy: 0.5991 - categorical_accuracy: 0.5991
# 127/127 - 76s - loss: 0.0251 - accuracy: 0.9916 - categorical_accuracy: 0.9916 - val_loss: 3.7335 - val_accuracy: 0.5873 - val_categorical_accuracy: 0.5873 - 76s/epoch - 598ms/step
# Epoch 36/50
# 64/64 [==============================] - 18s 282ms/step - loss: 3.6764 - accuracy: 0.5762 - categorical_accuracy: 0.5762
# 127/127 - 78s - loss: 0.1988 - accuracy: 0.9567 - categorical_accuracy: 0.9567 - val_loss: 3.4938 - val_accuracy: 0.5813 - val_categorical_accuracy: 0.5813 - 78s/epoch - 611ms/step
# Epoch 37/50
# 64/64 [==============================] - 20s 309ms/step - loss: 3.7275 - accuracy: 0.5850 - categorical_accuracy: 0.5850
# 127/127 - 76s - loss: 0.1101 - accuracy: 0.9673 - categorical_accuracy: 0.9673 - val_loss: 3.7163 - val_accuracy: 0.5739 - val_categorical_accuracy: 0.5739 - 76s/epoch - 598ms/step
# Epoch 38/50
# 64/64 [==============================] - 18s 283ms/step - loss: 3.9791 - accuracy: 0.5610 - categorical_accuracy: 0.5610
# 127/127 - 73s - loss: 0.1822 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - val_loss: 3.9579 - val_accuracy: 0.5575 - val_categorical_accuracy: 0.5575 - 73s/epoch - 577ms/step
# Epoch 39/50
# 64/64 [==============================] - 19s 289ms/step - loss: 4.1072 - accuracy: 0.5830 - categorical_accuracy: 0.5830
# 127/127 - 76s - loss: 0.1536 - accuracy: 0.9665 - categorical_accuracy: 0.9665 - val_loss: 4.1472 - val_accuracy: 0.5754 - val_categorical_accuracy: 0.5754 - 76s/epoch - 600ms/step
# Epoch 40/50
# 64/64 [==============================] - 18s 282ms/step - loss: 4.0116 - accuracy: 0.6118 - categorical_accuracy: 0.6118
# 127/127 - 73s - loss: 0.0981 - accuracy: 0.9724 - categorical_accuracy: 0.9724 - val_loss: 3.8717 - val_accuracy: 0.6146 - val_categorical_accuracy: 0.6146 - 73s/epoch - 572ms/step
# Epoch 41/50
# 64/64 [==============================] - 20s 312ms/step - loss: 4.2619 - accuracy: 0.5820 - categorical_accuracy: 0.5820
# 127/127 - 75s - loss: 0.0531 - accuracy: 0.9862 - categorical_accuracy: 0.9862 - val_loss: 4.3545 - val_accuracy: 0.5729 - val_categorical_accuracy: 0.5729 - 75s/epoch - 592ms/step
# Epoch 42/50
# 64/64 [==============================] - 18s 282ms/step - loss: 3.6512 - accuracy: 0.6045 - categorical_accuracy: 0.6045
# 127/127 - 78s - loss: 0.0833 - accuracy: 0.9811 - categorical_accuracy: 0.9811 - val_loss: 3.4981 - val_accuracy: 0.6186 - val_categorical_accuracy: 0.6186 - 78s/epoch - 616ms/step
# Epoch 43/50
# 64/64 [==============================] - 19s 298ms/step - loss: 3.1485 - accuracy: 0.6377 - categorical_accuracy: 0.6377
# 127/127 - 76s - loss: 0.0279 - accuracy: 0.9904 - categorical_accuracy: 0.9904 - val_loss: 3.1264 - val_accuracy: 0.6478 - val_categorical_accuracy: 0.6478 - 76s/epoch - 598ms/step
# Epoch 44/50
# 64/64 [==============================] - 18s 284ms/step - loss: 3.6371 - accuracy: 0.5967 - categorical_accuracy: 0.5967
# 127/127 - 73s - loss: 0.0294 - accuracy: 0.9916 - categorical_accuracy: 0.9916 - val_loss: 3.6767 - val_accuracy: 0.5972 - val_categorical_accuracy: 0.5972 - 73s/epoch - 579ms/step
# Epoch 45/50
# 64/64 [==============================] - 20s 313ms/step - loss: 3.9077 - accuracy: 0.6006 - categorical_accuracy: 0.6006
# 127/127 - 74s - loss: 0.1173 - accuracy: 0.9727 - categorical_accuracy: 0.9727 - val_loss: 3.8200 - val_accuracy: 0.6057 - val_categorical_accuracy: 0.6057 - 74s/epoch - 586ms/step
# Epoch 46/50
# 64/64 [==============================] - 18s 280ms/step - loss: 4.3429 - accuracy: 0.5786 - categorical_accuracy: 0.5786
# 127/127 - 75s - loss: 0.1187 - accuracy: 0.9732 - categorical_accuracy: 0.9732 - val_loss: 4.5016 - val_accuracy: 0.5878 - val_categorical_accuracy: 0.5878 - 75s/epoch - 589ms/step
# Epoch 47/50
# 64/64 [==============================] - 19s 289ms/step - loss: 4.1086 - accuracy: 0.5786 - categorical_accuracy: 0.5786
# 127/127 - 73s - loss: 0.0698 - accuracy: 0.9855 - categorical_accuracy: 0.9855 - val_loss: 4.1511 - val_accuracy: 0.5818 - val_categorical_accuracy: 0.5818 - 73s/epoch - 578ms/step
# Epoch 48/50
# 64/64 [==============================] - 18s 280ms/step - loss: 4.0156 - accuracy: 0.5898 - categorical_accuracy: 0.5898
# 127/127 - 72s - loss: 0.0905 - accuracy: 0.9801 - categorical_accuracy: 0.9801 - val_loss: 4.0208 - val_accuracy: 0.5908 - val_categorical_accuracy: 0.5908 - 72s/epoch - 570ms/step
# Epoch 49/50
# 64/64 [==============================] - 19s 293ms/step - loss: 5.5461 - accuracy: 0.5654 - categorical_accuracy: 0.5654
# 127/127 - 73s - loss: 0.0329 - accuracy: 0.9887 - categorical_accuracy: 0.9887 - val_loss: 5.5184 - val_accuracy: 0.5645 - val_categorical_accuracy: 0.5645 - 73s/epoch - 577ms/step
# Epoch 50/50
# 64/64 [==============================] - 18s 286ms/step - loss: 4.8279 - accuracy: 0.5723 - categorical_accuracy: 0.5723
# 127/127 - 73s - loss: 0.1373 - accuracy: 0.9707 - categorical_accuracy: 0.9707 - val_loss: 4.8685 - val_accuracy: 0.5660 - val_categorical_accuracy: 0.5660 - 73s/epoch - 572ms/step

# %%
pyplot.plot(history.history['accuracy'], label='train accuracy')
pyplot.plot(history.history['val_accuracy'], label='val accuracy')
pyplot.plot(test_metrics_callback.epoch_test_accuracy, label='test accuracy')
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(loc="upper right")
pyplot.show()

# %%
pyplot.plot(history.history['categorical_accuracy'], label='train categorical accuracy')
pyplot.plot(history.history['val_categorical_accuracy'], label='val categorical accuracy')
pyplot.plot(test_metrics_callback.epoch_test_categorical_accuracy, label='test categorical accuracy')
pyplot.ylabel('categorical accuracy')
pyplot.xlabel('epoch')
pyplot.legend(loc="upper right")
pyplot.show()

# %%
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.plot(test_metrics_callback.epoch_test_loss, label='test loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(loc="upper right")
pyplot.show()
