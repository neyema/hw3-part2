# %%
from matplotlib import pyplot
import pandas as pd

# %%
results = pd.read_csv("./yolov5-code/runs/train-cls/exp/results.csv")
results.head()
# Out:
#                      epoch               train/loss                 val/loss  \
# 0                        0                   3.2958                   2.1852
# 1                        1                   1.6508                   1.5478
# 2                        2                   1.2539                   1.3600
# 3                        3                   1.1120                   1.2936
# 4                        4                   1.0456                   1.2506
#
#         metrics/train_loss         metrics/val_loss        metrics/test_loss  \
# 0                  1.94190                   2.1852                   2.1769
# 1                  1.28790                   1.5478                   1.5399
# 2                  1.10220                   1.3600                   1.3548
# 3                  1.03320                   1.2936                   1.2858
# 4                  0.98975                   1.2506                   1.2466
#
#     metrics/train_accuracy     metrics/val_accuracy    metrics/test_accuracy  \
# 0                  0.84221                  0.75330                  0.75244
# 1                  0.96287                  0.89008                  0.88965
# 2                  0.98363                  0.92233                  0.91553
# 3                  0.99047                  0.92623                  0.92529
# 4                  0.99487                  0.93258                  0.92969
#
#                       lr/0
# 0                 0.000980
# 1                 0.000960
# 2                 0.000941
# 3                 0.000921
# 4                 0.000901

# %%
results.columns
# Out:
# Index(['                  epoch', '             train/loss',
#        '               val/loss', '     metrics/train_loss',
#        '       metrics/val_loss', '      metrics/test_loss',
#        ' metrics/train_accuracy', '   metrics/val_accuracy',
#        '  metrics/test_accuracy', '                   lr/0'],
#       dtype='object')

# %%
pyplot.plot(results[' metrics/train_accuracy'], label='train accuracy')
pyplot.plot(results['   metrics/val_accuracy'], label='val accuracy')
pyplot.plot(results['  metrics/test_accuracy'], label='test accuracy')
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(loc="upper right")
pyplot.show()

# %%
pyplot.plot(results['     metrics/train_loss'], label='train loss')
pyplot.plot(results['       metrics/val_loss'], label='val loss')
pyplot.plot(results['      metrics/test_loss'], label='test loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(loc="upper right")
pyplot.show()
